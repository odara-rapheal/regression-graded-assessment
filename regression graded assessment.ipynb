# %%
# importing required libraries
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ### Loading the Dataset

# %%
# reading the csv file and assigning it to a variable
energy_data = pd.read_csv("datasets/energydata_complete.csv")

# %%
# loading the dataset
energy_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
# getting information about the dataset
energy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
#  18  RH_8         19735 non-null  float64
#  19  T9           19735 non-null  float64
#  20  RH_9         19735 non-null  float64
#  21  T_out        19735 non-null  float64
#  22  Press_mm_hg  19735 non-null  float64
#  23  RH_out       19735 non-null  float64
#  24  Windspeed    19735 non-null  float64
#  25  Visibility   19735 non-null  float64
#  26  Tdewpoint    19735 non-null  float64
#  27  rv1          19735 non-null  float64
#  28  rv2          19735 non-null  float64
# dtypes: float64(26), int64(2), object(1)
# memory usage: 4.4+ MB

# %%
# getting a description of the dataset
energy_data.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# std        4.069813      2.006111      3.254576      2.042884      4.341321
# min       20.463333     17.200000     28.766667     15.100000     27.660000
# 25%       37.900000     20.790000     36.900000     19.530000     35.530000
# 50%       40.500000     22.100000     38.530000     20.666667     38.400000
# 75%       43.260000     23.290000     41.760000     22.100000     42.156667
# max       56.026667     29.236000     50.163333     26.200000     51.090000
#
#        ...            T9          RH_9         T_out   Press_mm_hg  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...     19.485828     41.552401      7.411665    755.522602
# std    ...      2.014712      4.151497      5.317409      7.399441
# min    ...     14.890000     29.166667     -5.000000    729.300000
# 25%    ...     18.000000     38.500000      3.666667    750.933333
# 50%    ...     19.390000     40.900000      6.916667    756.100000
# 75%    ...     20.600000     44.338095     10.408333    760.933333
# max    ...     24.500000     53.326667     26.100000    772.300000
#
#              RH_out     Windspeed    Visibility     Tdewpoint           rv1  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      79.750418      4.039752     38.330834      3.760707     24.988033
# std       14.901088      2.451221     11.794719      4.194648     14.496634
# min       24.000000      0.000000      1.000000     -6.600000      0.005322
# 25%       70.333333      2.000000     29.000000      0.900000     12.497889
# 50%       83.666667      3.666667     40.000000      3.433333     24.897653
# 75%       91.666667      5.500000     40.000000      6.566667     37.583769
# max      100.000000     14.000000     66.000000     15.500000     49.996530
#
#                 rv2
# count  19735.000000
# mean      24.988033
# std       14.496634
# min        0.005322
# 25%       12.497889
# 50%       24.897653
# 75%       37.583769
# max       49.996530
#
# [8 rows x 28 columns]

# %%
# checking for empty fields in the dataset
energy_data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# since there is no empty field in the dataset, we proceed further

# %%
# dropping the date and lights columns
new_df = energy_data.drop(["date", "lights"], axis = 1)

# %%
new_df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# 0      44.730000  19.000000  45.566667  17.166667  ...  17.033333  45.5300
# 1      44.790000  19.000000  45.992500  17.166667  ...  17.066667  45.5600
# 2      44.933333  18.926667  45.890000  17.166667  ...  17.000000  45.5000
# 3      45.000000  18.890000  45.723333  17.166667  ...  17.000000  45.4000
# 4      45.000000  18.890000  45.530000  17.200000  ...  17.000000  45.4000
# ...          ...        ...        ...        ...  ...        ...      ...
# 19730  41.163333  24.700000  45.590000  23.200000  ...  23.200000  46.7900
# 19731  41.223333  24.700000  45.590000  23.230000  ...  23.200000  46.7900
# 19732  41.690000  24.700000  45.730000  23.230000  ...  23.200000  46.7900
# 19733  41.290000  24.700000  45.790000  23.200000  ...  23.200000  46.8175
# 19734  41.156667  24.700000  45.963333  23.200000  ...  23.200000  46.8450
#
#            T_out  Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint  \
# 0       6.600000        733.5  92.000000   7.000000   63.000000   5.300000
# 1       6.483333        733.6  92.000000   6.666667   59.166667   5.200000
# 2       6.366667        733.7  92.000000   6.333333   55.333333   5.100000
# 3       6.250000        733.8  92.000000   6.000000   51.500000   5.000000
# 4       6.133333        733.9  92.000000   5.666667   47.666667   4.900000
# ...          ...          ...        ...        ...         ...        ...
# 19730  22.733333        755.2  55.666667   3.333333   23.666667  13.333333
# 19731  22.600000        755.2  56.000000   3.500000   24.500000  13.300000
# 19732  22.466667        755.2  56.333333   3.666667   25.333333  13.266667
# 19733  22.333333        755.2  56.666667   3.833333   26.166667  13.233333
# 19734  22.200000        755.2  57.000000   4.000000   27.000000  13.200000
#
#              rv1        rv2
# 0      13.275433  13.275433
# 1      18.606195  18.606195
# 2      28.642668  28.642668
# 3      45.410389  45.410389
# 4      10.084097  10.084097
# ...          ...        ...
# 19730  43.096812  43.096812
# 19731  49.282940  49.282940
# 19732  29.199117  29.199117
# 19733   6.322784   6.322784
# 19734  34.118851  34.118851
#
# [19735 rows x 27 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 27 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Appliances   19735 non-null  int64
#  1   T1           19735 non-null  float64
#  2   RH_1         19735 non-null  float64
#  3   T2           19735 non-null  float64
#  4   RH_2         19735 non-null  float64
#  5   T3           19735 non-null  float64
#  6   RH_3         19735 non-null  float64
#  7   T4           19735 non-null  float64
#  8   RH_4         19735 non-null  float64
#  9   T5           19735 non-null  float64
#  10  RH_5         19735 non-null  float64
#  11  T6           19735 non-null  float64
#  12  RH_6         19735 non-null  float64
#  13  T7           19735 non-null  float64
#  14  RH_7         19735 non-null  float64
#  15  T8           19735 non-null  float64
#  16  RH_8         19735 non-null  float64
#  17  T9           19735 non-null  float64
#  18  RH_9         19735 non-null  float64
#  19  T_out        19735 non-null  float64
#  20  Press_mm_hg  19735 non-null  float64
#  21  RH_out       19735 non-null  float64
#  22  Windspeed    19735 non-null  float64
#  23  Visibility   19735 non-null  float64
#  24  Tdewpoint    19735 non-null  float64
#  25  rv1          19735 non-null  float64
#  26  rv2          19735 non-null  float64
# dtypes: float64(26), int64(1)
# memory usage: 4.1 MB

# %%
# rearranging the order of the new_df dataframe by moving
# the "Appliances" column to the last column
mid = new_df['Appliances']
new_df.drop(labels = ['Appliances'], axis=1, inplace = True)
new_df.insert(26, 'Appliances', mid)
new_df
# Out:
#               T1       RH_1         T2       RH_2         T3       RH_3  \
# 0      19.890000  47.596667  19.200000  44.790000  19.790000  44.730000
# 1      19.890000  46.693333  19.200000  44.722500  19.790000  44.790000
# 2      19.890000  46.300000  19.200000  44.626667  19.790000  44.933333
# 3      19.890000  46.066667  19.200000  44.590000  19.790000  45.000000
# 4      19.890000  46.333333  19.200000  44.530000  19.790000  45.000000
# ...          ...        ...        ...        ...        ...        ...
# 19730  25.566667  46.560000  25.890000  42.025714  27.200000  41.163333
# 19731  25.500000  46.500000  25.754000  42.080000  27.133333  41.223333
# 19732  25.500000  46.596667  25.628571  42.768571  27.050000  41.690000
# 19733  25.500000  46.990000  25.414000  43.036000  26.890000  41.290000
# 19734  25.500000  46.600000  25.264286  42.971429  26.823333  41.156667
#
#               T4       RH_4         T5       RH_5  ...     RH_9      T_out  \
# 0      19.000000  45.566667  17.166667  55.200000  ...  45.5300   6.600000
# 1      19.000000  45.992500  17.166667  55.200000  ...  45.5600   6.483333
# 2      18.926667  45.890000  17.166667  55.090000  ...  45.5000   6.366667
# 3      18.890000  45.723333  17.166667  55.090000  ...  45.4000   6.250000
# 4      18.890000  45.530000  17.200000  55.090000  ...  45.4000   6.133333
# ...          ...        ...        ...        ...  ...      ...        ...
# 19730  24.700000  45.590000  23.200000  52.400000  ...  46.7900  22.733333
# 19731  24.700000  45.590000  23.230000  52.326667  ...  46.7900  22.600000
# 19732  24.700000  45.730000  23.230000  52.266667  ...  46.7900  22.466667
# 19733  24.700000  45.790000  23.200000  52.200000  ...  46.8175  22.333333
# 19734  24.700000  45.963333  23.200000  52.200000  ...  46.8450  22.200000
#
#        Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# 0            733.5  92.000000   7.000000   63.000000   5.300000  13.275433
# 1            733.6  92.000000   6.666667   59.166667   5.200000  18.606195
# 2            733.7  92.000000   6.333333   55.333333   5.100000  28.642668
# 3            733.8  92.000000   6.000000   51.500000   5.000000  45.410389
# 4            733.9  92.000000   5.666667   47.666667   4.900000  10.084097
# ...            ...        ...        ...         ...        ...        ...
# 19730        755.2  55.666667   3.333333   23.666667  13.333333  43.096812
# 19731        755.2  56.000000   3.500000   24.500000  13.300000  49.282940
# 19732        755.2  56.333333   3.666667   25.333333  13.266667  29.199117
# 19733        755.2  56.666667   3.833333   26.166667  13.233333   6.322784
# 19734        755.2  57.000000   4.000000   27.000000  13.200000  34.118851
#
#              rv2  Appliances
# 0      13.275433          60
# 1      18.606195          60
# 2      28.642668          50
# 3      45.410389          50
# 4      10.084097          60
# ...          ...         ...
# 19730  43.096812         100
# 19731  49.282940          90
# 19732  29.199117         270
# 19733   6.322784         420
# 19734  34.118851         430
#
# [19735 rows x 27 columns]

# %%
new_df.count()
# Out:
# T1             19735
# RH_1           19735
# T2             19735
# RH_2           19735
# T3             19735
# RH_3           19735
# T4             19735
# RH_4           19735
# T5             19735
# RH_5           19735
# T6             19735
# RH_6           19735
# T7             19735
# RH_7           19735
# T8             19735
# RH_8           19735
# T9             19735
# RH_9           19735
# T_out          19735
# Press_mm_hg    19735
# RH_out         19735
# Windspeed      19735
# Visibility     19735
# Tdewpoint      19735
# rv1            19735
# rv2            19735
# Appliances     19735
# dtype: int64

# %% [markdown]
# ### Scaling

# %%
# carrying out scaling on the dataset before splitting
# applying the Min Max Scaler technique using Fit Transform.

# retrieving just the numeric input values
data = new_df.values[:, :]

# performing a robust scaler transform of the dataset
trans = MinMaxScaler()
data = trans.fit_transform(data)

# convering the array back to a dataframe
scaled_dataset = pd.DataFrame(data, columns = ["T1", "RH_1", "T2", "RH_2", "T3", "RH_3", "T4", "RH_4", "T5", "RH_5", "T6", "RH_6", "T7", "RH_7", "T8", "RH_8", "T9", "RH_9", "T_out", "Press_mm_hg", "RH_out", "Windspeed", "Visibility", "Tdewpoint", "rv1", "rv2", "Appliances"])

# %%
# loading the scaled dataset
scaled_dataset
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
#            RH_4        T5      RH_5  ...      RH_9     T_out  Press_mm_hg  \
# 0      0.764262  0.175506  0.381691  ...  0.677290  0.372990     0.097674
# 1      0.782437  0.175506  0.381691  ...  0.678532  0.369239     0.100000
# 2      0.778062  0.175506  0.380037  ...  0.676049  0.365488     0.102326
# 3      0.770949  0.175506  0.380037  ...  0.671909  0.361736     0.104651
# 4      0.762697  0.178691  0.380037  ...  0.671909  0.357985     0.106977
# ...         ...       ...       ...  ...       ...       ...          ...
# 19730  0.765258  0.752031  0.339590  ...  0.729443  0.891747     0.602326
# 19731  0.765258  0.754897  0.338487  ...  0.729443  0.887460     0.602326
# 19732  0.771233  0.754897  0.337585  ...  0.729443  0.883173     0.602326
# 19733  0.773794  0.752031  0.336583  ...  0.730581  0.878885     0.602326
# 19734  0.781192  0.752031  0.336583  ...  0.731719  0.874598     0.602326
#
#          RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2  \
# 0      0.894737   0.500000    0.953846   0.538462  0.265449  0.265449
# 1      0.894737   0.476190    0.894872   0.533937  0.372083  0.372083
# 2      0.894737   0.452381    0.835897   0.529412  0.572848  0.572848
# 3      0.894737   0.428571    0.776923   0.524887  0.908261  0.908261
# 4      0.894737   0.404762    0.717949   0.520362  0.201611  0.201611
# ...         ...        ...         ...        ...       ...       ...
# 19730  0.416667   0.238095    0.348718   0.901961  0.861981  0.861981
# 19731  0.421053   0.250000    0.361538   0.900452  0.985726  0.985726
# 19732  0.425439   0.261905    0.374359   0.898944  0.583979  0.583979
# 19733  0.429825   0.273810    0.387179   0.897436  0.126371  0.126371
# 19734  0.434211   0.285714    0.400000   0.895928  0.682391  0.682391
#
#        Appliances
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
# ...           ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
#
# [19735 rows x 27 columns]

# %% [markdown]
# We can see that the distributions have been adjusted and that the minimum and maximum values for each variable are now a crisp 0.0 and 1.0 respectively.

# %%
# summarizing the dataset
scaled_dataset.describe()
# Out:
#                  T1          RH_1            T2          RH_2            T3  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.517061      0.364271      0.308303      0.561170      0.421038
# std        0.169595      0.109512      0.159412      0.114438      0.166676
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.419219      0.283735      0.195542      0.490299      0.298272
# 50%        0.507920      0.347675      0.283499      0.563408      0.407112
# 75%        0.613516      0.441519      0.392537      0.641016      0.505982
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                RH_3            T4          RH_4            T5          RH_5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.489601      0.518499      0.485143      0.407272      0.317777
# std        0.152107      0.184044      0.185289      0.176266      0.135656
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.380122      0.399099      0.335894      0.281653      0.234337
# 50%        0.456302      0.501502      0.458387      0.387960      0.289821
# 75%        0.607260      0.630631      0.618722      0.505460      0.358586
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...          RH_9         T_out   Press_mm_hg        RH_out  \
# count  ...  19735.000000  19735.000000  19735.000000  19735.000000
# mean   ...      0.512655      0.399089      0.609828      0.733558
# std    ...      0.171833      0.170978      0.172080      0.196067
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.386313      0.278671      0.503101      0.609649
# 50%    ...      0.485651      0.383173      0.623256      0.785088
# 75%    ...      0.627956      0.495445      0.735659      0.890351
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#           Windspeed    Visibility     Tdewpoint           rv1           rv2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean       0.288554      0.574321      0.468810      0.499742      0.499742
# std        0.175087      0.181457      0.189803      0.289984      0.289984
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.142857      0.430769      0.339367      0.249895      0.249895
# 50%        0.261905      0.600000      0.453997      0.497934      0.497934
# 75%        0.392857      0.600000      0.595777      0.751701      0.751701
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          Appliances
# count  19735.000000
# mean       0.081958
# std        0.095818
# min        0.000000
# 25%        0.037383
# 50%        0.046729
# 75%        0.084112
# max        1.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ### Training & Testing Data

# %%
# defining the dependent and independent variables
X = scaled_dataset.loc[:, ["T2"]].values
y = scaled_dataset.loc[:, ["T6"]].values

# %%
# splitting the scaled_dataset into the Training set and Test set using train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# fitting our Multiple Linear Regression to the Training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predicting the Test set results
y_test_pred = regressor.predict(X_test)

# %%
y_test_pred
# Out:
# array([[0.23928945],
#        [0.46794238],
#        [0.23108472],
#        ...,
#        [0.3001772 ],
#        [0.4297256 ],
#        [0.3217686 ]])

# %%
# printing the intercept of the trained model
print('Intercept: \n', regressor.intercept_)
# Out:
# Intercept:
#  [0.13176428]

# %%
# printing the coefficients of the trained model
print('Coefficients: \n', regressor.coef_)
# Out:
# Coefficients:
#  [[0.8910771]]

# %%
# showing the output of the model prediction in a dataframe
y_test_pred_df = pd.DataFrame(y_test_pred, columns = ["Predicted Appliances"])

# %%
# displaying the first 20 field of the dataframe
y_test_pred_df.head(20)
# Out:
#     Predicted Appliances
# 0               0.239289
# 1               0.467942
# 2               0.231085
# 3               0.636355
# 4               0.155299
# 5               0.442033
# 6               0.182936
# 7               0.423248
# 8               0.351997
# 9               0.237346
# 10              0.500329
# 11              0.449158
# 12              0.351997
# 13              0.364951
# 14              0.459954
# 15              0.291541
# 16              0.364951
# 17              0.241233
# 18              0.332564
# 19              0.429726

# %%
# R^2 value in two D.P
r2_score(y_test, y_test_pred)
# Out:
# 0.6427789637197382

# %% [markdown]
# ### Building the optimal model using Backward Elimination

# %%
# adding the column of ones to our matrix of features X
new_X = np.append(arr = np.ones((19735, 1)).astype(int), values = X, axis = 1)

# %%
# loading the new matrix of features
new_X
# Out:
# array([[1.        , 0.22534529],
#        [1.        , 0.22534529],
#        [1.        , 0.22534529],
#        ...,
#        [1.        , 0.69265118],
#        [1.        , 0.67705355],
#        [1.        , 0.66617051]])

# %%
# turning the new_X varaible into a dataframe
new_X_df = pd.DataFrame(new_X, columns = ["constant", "T2"])

# %%
new_X_df
# Out:
#        constant        T2
# 0           1.0  0.225345
# 1           1.0  0.225345
# 2           1.0  0.225345
# 3           1.0  0.225345
# 4           1.0  0.225345
# ...         ...       ...
# 19730       1.0  0.711655
# 19731       1.0  0.701769
# 19732       1.0  0.692651
# 19733       1.0  0.677054
# 19734       1.0  0.666171
#
# [19735 rows x 2 columns]

# %%
# selecting all the independent variables for initial test
# before backward elimination if necessary
X_opt = new_X_df.loc[:, ["constant", "T2"]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.642
# Model:                            OLS   Adj. R-squared:                  0.642
# Method:                 Least Squares   F-statistic:                 3.537e+04
# Date:                Sun, 29 Aug 2021   Prob (F-statistic):               0.00
# Time:                        05:13:11   Log-Likelihood:                 16273.
# No. Observations:               19735   AIC:                        -3.254e+04
# Df Residuals:                   19733   BIC:                        -3.253e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# constant       0.1321      0.002     80.354      0.000       0.129       0.135
# T2             0.8910      0.005    188.073      0.000       0.882       0.900
# ==============================================================================
# Omnibus:                      842.252   Durbin-Watson:                   0.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              964.072
# Skew:                          -0.510   Prob(JB):                    4.51e-210
# Kurtosis:                       3.365   Cond. No.                         6.88
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Performance Metrics

# %%
# calculating the mean absolute error (MAE) in 2 D.P
mae = mean_absolute_error(y_test, y_test_pred)
print("The Mean Absolute Error (MAE) is %.3f" %mae)
# Out:
# The Mean Absolute Error (MAE) is 0.082

# %%
# calculating the sum of squared residual in 2 D.P
print(regressor_OLS.ssr)
# Out:
# 222.087783828228

# %%
# calculating the root mean squared error in 3 D.P
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print("The Root Mean Squared Error (RMSE) is %.3f" %rmse)
# Out:
# The Root Mean Squared Error (RMSE) is 0.106

# %%
# coefficient of determination in 2 D.P
cod = r2_score(y_test, y_test_pred)
print("The Coefficient of Determination is %.3f" %cod)
# Out:
# The Coefficient of Determination is 0.643

# %%
# defining the dependent and independent variables
X = scaled_dataset.iloc[:, :-1 ].values
y = scaled_dataset.loc[:, ["Appliances"] ].values

# %%
# splitting the scaled_dataset into the Training set and Test set using train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# fitting our Multiple Linear Regression to the Training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predicting the Test set results
y_test_pred = regressor.predict(X_test)

# %%
y_test_pred
# Out:
# array([[0.03322207],
#        [0.24411599],
#        [0.03400024],
#        ...,
#        [0.06844707],
#        [0.10032325],
#        [0.05722198]])

# %%
# printing the intercept of the trained model
print('Intercept: \n', regressor.intercept_)
# Out:
# Intercept:
#  [0.15290296]

# %%
# printing the coefficients of the trained model
print('Coefficients: \n', regressor.coef_)
# Out:
# Coefficients:
#  [[-0.00328105  0.5535466  -0.23617792 -0.45669795  0.29062714  0.09604827
#    0.028981    0.02638578 -0.01565684  0.01600579  0.23642491  0.03804865
#    0.01031878 -0.04461364  0.10199505 -0.15759548 -0.18994077 -0.03980032
#   -0.32185967  0.00683933 -0.07767065  0.02918313  0.01230661  0.11775773
#    0.0007701   0.0007701 ]]

# %%
# showing the output of the model prediction in a dataframe
y_test_pred_df = pd.DataFrame(y_test_pred, columns = ["Predicted Appliances"])

# %%
# displaying the first 20 field of the dataframe
y_test_pred_df.head(20)
# Out:
#     Predicted Appliances
# 0               0.033222
# 1               0.244116
# 2               0.034000
# 3               0.105377
# 4               0.023360
# 5               0.162821
# 6               0.074288
# 7               0.163705
# 8               0.075069
# 9               0.101717
# 10              0.147930
# 11              0.103840
# 12              0.143094
# 13              0.085840
# 14              0.116415
# 15              0.037074
# 16              0.051698
# 17              0.046931
# 18              0.040440
# 19              0.120882

# %% [markdown]
# ### Building the optimal model using Backward Elimination

# %%
# adding the column of ones to our matrix of features X
new_X = np.append(arr = np.ones((19735, 1)).astype(int), values = X, axis = 1)

# %%
# loading the new matrix of features
new_X
# Out:
# array([[1.        , 0.32734952, 0.56618659, ..., 0.53846154, 0.26544891,
#         0.26544891],
#        [1.        , 0.32734952, 0.54132648, ..., 0.53393665, 0.37208289,
#         0.37208289],
#        [1.        , 0.32734952, 0.53050179, ..., 0.52941176, 0.57284766,
#         0.57284766],
#        ...,
#        [1.        , 0.91974657, 0.53866618, ..., 0.89894419, 0.58397859,
#         0.58397859],
#        [1.        , 0.91974657, 0.54949087, ..., 0.8974359 , 0.12637146,
#         0.12637146],
#        [1.        , 0.91974657, 0.53875791, ..., 0.8959276 , 0.68239057,
#         0.68239057]])

# %%
# turning the new_X varaible into a dataframe
new_X_df = pd.DataFrame(new_X, columns = ["constant", "T1", "RH_1", "T2", "RH_2", "T3", "RH_3", "T4", "RH_4", "T5", "RH_5", "T6", "RH_6", "T7", "RH_7", "T8", "RH_8", "T9", "RH_9", "T_out", "Press_mm_hg", "RH_out", "Windspeed", "Visibility", "Tdewpoint", "rv1", "rv2"])

# %%
new_X_df
# Out:
#        constant        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0           1.0  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1           1.0  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2           1.0  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3           1.0  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4           1.0  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730       1.0  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731       1.0  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732       1.0  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733       1.0  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734       1.0  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
#              T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0      0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1      0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2      0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3      0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4      0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
# ...         ...       ...       ...  ...       ...       ...       ...
# 19730  0.864865  0.765258  0.752031  ...  0.864724  0.729443  0.891747
# 19731  0.864865  0.765258  0.754897  ...  0.864724  0.729443  0.887460
# 19732  0.864865  0.771233  0.754897  ...  0.864724  0.729443  0.883173
# 19733  0.864865  0.773794  0.752031  ...  0.864724  0.730581  0.878885
# 19734  0.864865  0.781192  0.752031  ...  0.864724  0.731719  0.874598
#
#        Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1  \
# 0         0.097674  0.894737   0.500000    0.953846   0.538462  0.265449
# 1         0.100000  0.894737   0.476190    0.894872   0.533937  0.372083
# 2         0.102326  0.894737   0.452381    0.835897   0.529412  0.572848
# 3         0.104651  0.894737   0.428571    0.776923   0.524887  0.908261
# 4         0.106977  0.894737   0.404762    0.717949   0.520362  0.201611
# ...            ...       ...        ...         ...        ...       ...
# 19730     0.602326  0.416667   0.238095    0.348718   0.901961  0.861981
# 19731     0.602326  0.421053   0.250000    0.361538   0.900452  0.985726
# 19732     0.602326  0.425439   0.261905    0.374359   0.898944  0.583979
# 19733     0.602326  0.429825   0.273810    0.387179   0.897436  0.126371
# 19734     0.602326  0.434211   0.285714    0.400000   0.895928  0.682391
#
#             rv2
# 0      0.265449
# 1      0.372083
# 2      0.572848
# 3      0.908261
# 4      0.201611
# ...         ...
# 19730  0.861981
# 19731  0.985726
# 19732  0.583979
# 19733  0.126371
# 19734  0.682391
#
# [19735 rows x 27 columns]

# %%
# selecting all the independent variables for initial test
# before backward elimination if necessary
X_opt = new_X_df.loc[:, ["constant", "T1", "RH_1", "T2", "RH_2", "T3", "RH_3", "T4", "RH_4", "T5", "RH_5", "T6", "RH_6", "T7", "RH_7", "T8", "RH_8", "T9", "RH_9", "T_out", "Press_mm_hg", "RH_out", "Windspeed", "Visibility", "Tdewpoint", "rv1", "rv2"]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     135.3
# Date:                Sun, 29 Aug 2021   Prob (F-statistic):               0.00
# Time:                        06:42:18   Log-Likelihood:                 19845.
# No. Observations:               19735   AIC:                        -3.964e+04
# Df Residuals:                   19709   BIC:                        -3.943e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# constant        0.1552      0.020      7.638      0.000       0.115       0.195
# T1              0.0035      0.016      0.209      0.834      -0.029       0.036
# RH_1            0.5457      0.023     23.775      0.000       0.501       0.591
# T2             -0.2611      0.021    -12.333      0.000      -0.303      -0.220
# RH_2           -0.4791      0.026    -18.612      0.000      -0.530      -0.429
# T3              0.2854      0.012     23.858      0.000       0.262       0.309
# RH_3            0.1010      0.014      7.404      0.000       0.074       0.128
# T4              0.0309      0.010      3.019      0.003       0.011       0.051
# RH_4            0.0427      0.014      3.070      0.002       0.015       0.070
# T5             -0.0002      0.012     -0.017      0.987      -0.023       0.023
# RH_5            0.0148      0.005      2.716      0.007       0.004       0.025
# T6              0.2459      0.021     11.961      0.000       0.206       0.286
# RH_6            0.0321      0.006      5.075      0.000       0.020       0.044
# T7              0.0112      0.013      0.844      0.399      -0.015       0.037
# RH_7           -0.0485      0.011     -4.246      0.000      -0.071      -0.026
# T8              0.1036      0.010     10.423      0.000       0.084       0.123
# RH_8           -0.1610      0.010    -15.874      0.000      -0.181      -0.141
# T9             -0.1984      0.016    -12.585      0.000      -0.229      -0.167
# RH_9           -0.0340      0.009     -3.644      0.000      -0.052      -0.016
# T_out          -0.3093      0.045     -6.921      0.000      -0.397      -0.222
# Press_mm_hg     0.0050      0.004      1.139      0.255      -0.004       0.013
# RH_out         -0.0647      0.023     -2.866      0.004      -0.109      -0.020
# Windspeed       0.0279      0.005      6.110      0.000       0.019       0.037
# Visibility      0.0107      0.004      3.012      0.003       0.004       0.018
# Tdewpoint       0.1048      0.031      3.401      0.001       0.044       0.165
# rv1            -0.0010      0.001     -0.880      0.379      -0.003       0.001
# rv2            -0.0010      0.001     -0.880      0.379      -0.003       0.001
# ==============================================================================
# Omnibus:                    14033.514   Durbin-Watson:                   0.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           213085.400
# Skew:                           3.344   Prob(JB):                         0.00
# Kurtosis:                      17.642   Cond. No.                     1.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.19e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# from the summary above, it can be observed that the features with the highest and lowest weights are **RH_2** with a weight of **-0.4791** and **RH_1** with a weight of **0.5457**

# %%
# training with a Ridge model with an alpha value of 0.4
ridge_reg = Ridge(alpha = 0.4)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
y_test_pred = ridge_reg.predict(X_test)

# %%
# calculating the root mean squared error in 3 D.P
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print("The Root Mean Squared Error (RMSE) is %.3f" %rmse)
# Out:
# The Root Mean Squared Error (RMSE) is 0.088

# %% [markdown]
# It can be observed that there is a change in the root mean squared error (RMSE) when trained with a Ridge Regression Model.

# %%
# training with a Lassso model with an alpha value of 0.001
lasso_reg = Lasso(alpha = 0.001)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
y_test_pred = lasso_reg.predict(X_test)

# %%
y_test_pred
# Out:
# array([0.07370267, 0.08143458, 0.07716072, ..., 0.07792848, 0.09034412,
#        0.08359255])

# %%
# selecting all the independent variables for initial test
# before backward elimination if necessary
X_opt = new_X_df.loc[:, ["constant", "T1", "RH_1", "T2", "RH_2", "T3", "RH_3", "T4", "RH_4", "T5", "RH_5", "T6", "RH_6", "T7", "RH_7", "T8", "RH_8", "T9", "RH_9", "T_out", "Press_mm_hg", "RH_out", "Windspeed", "Visibility", "Tdewpoint", "rv1", "rv2"]]
lasso_reg_OLS = sm.OLS(endog = y, exog = X_opt).fit()
lasso_reg_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.145
# Method:                 Least Squares   F-statistic:                     135.3
# Date:                Sun, 29 Aug 2021   Prob (F-statistic):               0.00
# Time:                        07:28:24   Log-Likelihood:                 19845.
# No. Observations:               19735   AIC:                        -3.964e+04
# Df Residuals:                   19709   BIC:                        -3.943e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# constant        0.1552      0.020      7.638      0.000       0.115       0.195
# T1              0.0035      0.016      0.209      0.834      -0.029       0.036
# RH_1            0.5457      0.023     23.775      0.000       0.501       0.591
# T2             -0.2611      0.021    -12.333      0.000      -0.303      -0.220
# RH_2           -0.4791      0.026    -18.612      0.000      -0.530      -0.429
# T3              0.2854      0.012     23.858      0.000       0.262       0.309
# RH_3            0.1010      0.014      7.404      0.000       0.074       0.128
# T4              0.0309      0.010      3.019      0.003       0.011       0.051
# RH_4            0.0427      0.014      3.070      0.002       0.015       0.070
# T5             -0.0002      0.012     -0.017      0.987      -0.023       0.023
# RH_5            0.0148      0.005      2.716      0.007       0.004       0.025
# T6              0.2459      0.021     11.961      0.000       0.206       0.286
# RH_6            0.0321      0.006      5.075      0.000       0.020       0.044
# T7              0.0112      0.013      0.844      0.399      -0.015       0.037
# RH_7           -0.0485      0.011     -4.246      0.000      -0.071      -0.026
# T8              0.1036      0.010     10.423      0.000       0.084       0.123
# RH_8           -0.1610      0.010    -15.874      0.000      -0.181      -0.141
# T9             -0.1984      0.016    -12.585      0.000      -0.229      -0.167
# RH_9           -0.0340      0.009     -3.644      0.000      -0.052      -0.016
# T_out          -0.3093      0.045     -6.921      0.000      -0.397      -0.222
# Press_mm_hg     0.0050      0.004      1.139      0.255      -0.004       0.013
# RH_out         -0.0647      0.023     -2.866      0.004      -0.109      -0.020
# Windspeed       0.0279      0.005      6.110      0.000       0.019       0.037
# Visibility      0.0107      0.004      3.012      0.003       0.004       0.018
# Tdewpoint       0.1048      0.031      3.401      0.001       0.044       0.165
# rv1            -0.0010      0.001     -0.880      0.379      -0.003       0.001
# rv2            -0.0010      0.001     -0.880      0.379      -0.003       0.001
# ==============================================================================
# Omnibus:                    14033.514   Durbin-Watson:                   0.608
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           213085.400
# Skew:                           3.344   Prob(JB):                         0.00
# Kurtosis:                      17.642   Cond. No.                     1.09e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.19e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# calculating the root mean squared error in 3 D.P
rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
print("The Root Mean Squared Error (RMSE) is %.3f" %rmse)
# Out:
# The Root Mean Squared Error (RMSE) is 0.094
